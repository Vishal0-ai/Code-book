# %% [markdown]
# # A Project on Data Science Purely Based on Python

# %% [markdown]
# ## Description of project:-
#   Analyzing a data dump of CodeBook users using pure Python. Your job is to load and explore the data to understand its structure.
#
#   Data was provided by the user or company.
#
#   Task 1: Load the User Data

# %%
import json

# %%
#Function to load Data:- 

def load_data(File):
    with open(File,"r") as F:
        Data=json.load(F)
    return Data

# %%
Data=load_data("Data.json")
Data
# Out:
# {'users': [{'id': 1,
#    'name': 'Amit',
#    'age': 22,
#    'city': 'Delhi',
#    'friends': [2, 3, 5],
#    'liked_pages': [101, 103]},
#   {'id': 2,
#    'name': 'Priya',
#    'age': 21,
#    'city': 'Mumbai',
#    'friends': [1, 4, 6],
#    'liked_pages': [102, 104]},
#   {'id': 3,
#    'name': 'Rahul',
#    'age': 23,
#    'city': 'Bangalore',
#    'friends': [1, 5, 7],
#    'liked_pages': [101, 103, 105]},
#   {'id': 4,
#    'name': 'Sara',
#    'age': 22,
#    'city': 'Pune',
#    'friends': [2, 6, 8],
#    'liked_pages': [104, 106]},
#   {'id': 5,
#    'name': 'Karan',
#    'age': 24,
#    'city': 'Delhi',
#    'friends': [1, 3, 7],
#    'liked_pages': [101, 105]},
#   {'id': 6,
#    'name': 'Neha',
#    'age': 20,
#    'city': 'Hyderabad',
#    'friends': [2, 4, 8],
#    'liked_pages': [102, 106]},
#   {'id': 7,
#    'name': 'Rohan',
#    'age': 25,
#    'city': 'Chandigarh',
#    'friends': [3, 5, 8],
#    'liked_pages': [103, 105, 107]},
#   {'id': 8,
# ...

# %%
# Write a Function to Display User Friends and likes
def display_users(data):
    print("Users and Their Connections:\n")
    for user in data["users"]:
        print(f"{user['name']} (ID: {user['id']}) - Friends: {user['friends']} - Liked Pages: {user['liked_pages']}")
    print("\nPages:\n")
    for page in data["pages"]:
        print(f"{page['id']}: {page['name']}")
data = load_data("Data.json")
display_users(data)
# Out:
# Users and Their Connections:
#
# Amit (ID: 1) - Friends: [2, 3, 5] - Liked Pages: [101, 103]
# Priya (ID: 2) - Friends: [1, 4, 6] - Liked Pages: [102, 104]
# Rahul (ID: 3) - Friends: [1, 5, 7] - Liked Pages: [101, 103, 105]
# Sara (ID: 4) - Friends: [2, 6, 8] - Liked Pages: [104, 106]
# Karan (ID: 5) - Friends: [1, 3, 7] - Liked Pages: [101, 105]
# Neha (ID: 6) - Friends: [2, 4, 8] - Liked Pages: [102, 106]
# Rohan (ID: 7) - Friends: [3, 5, 8] - Liked Pages: [103, 105, 107]
# Anjali (ID: 8) - Friends: [4, 6, 7] - Liked Pages: [104, 106, 108]
# Vikas (ID: 9) - Friends: [1, 4, 7] - Liked Pages: [101, 107]
# Pooja (ID: 10) - Friends: [2, 5, 9] - Liked Pages: [102, 108]
#
# Pages:
#
# 101: Python Developers
# 102: Data Science Enthusiasts
# 103: AI & ML Community
# 104: Web Dev Hub
# 105: Machine Learning Beginners
# 106: Cloud Computing Community
# 107: Cyber Security World
# 108: Technology News
